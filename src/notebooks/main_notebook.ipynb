# %%
# %load_ext autoreload
# %autoreload 2

import configparser
import os.path
from os import path
from importlib import reload

WANDB_enable = False
creds_path_ar = ["credentials.colab.ini"]
root_path = ""
data_path = ""

for creds_path in creds_path_ar:
  if path.exists(creds_path):
      print(creds_path)
      config_parser = configparser.ConfigParser()
      config_parser.read(creds_path)
      root_path = config_parser['MAIN']["PATH_ROOT"]
      # data_path = config_parser['MAIN']["PATH_DATA"]
      ENV = config_parser['MAIN']["ENV"]
      WANDB_LOGIN = config_parser['MAIN']['WANDB_LOGIN']
      break

if ENV=="COLAB":
  from google.colab import drive
  drive.mount('/content/drive')
  os.environ["WANDB_API_KEY"] = WANDB_LOGIN
# Out:
# credentials.colab.ini
# Mounted at /content/drive

# %%
# %%capture
# !pip install numpy
# !pip install pygame
# !pip install wandb
# !pip install zope.interface
# !pip3 install torch==1.2.0+cu92 torchvision==0.4.0+cu92 -f https://download.pytorch.org/whl/torch_stable.html

# %%
cd {root_path}
# Out:
# /content/drive/My Drive/projects/snake-ai-pytorch

# %%
import os
import wandb

os.environ["SDL_VIDEODRIVER"] = "dummy"
wandb_setttings = wandb.Settings(start_method="thread")


from src.agent import train
train('split-collision', 0, agent_kwargs={"n_features": 11}, note=None, wandb_mode="disabled",)
# Out:
# pygame 2.1.2 (SDL 2.0.16, Python 3.7.14)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# /content/drive/My Drive/projects/snake-ai-pytorch/src/model.py:38: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   next_state = torch.tensor(next_state, dtype=torch.float)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-55e7af7dbede> in <module>
#       7
#       8 from src.agent import train
# ----> 9 train('split-collision', 0, agent_kwargs={"n_features": 11}, note=None, wandb_mode="disabled",)
#
# /content/drive/My Drive/projects/snake-ai-pytorch/src/agent.py in train(group, run, note, wandb_mode, wandb_setttings, agent_kwargs)
#     400
#     401         # train short memory
# --> 402         agent.train_short_memory(state_old, final_move, reward, state_new, done)
#     403
#     404         # remember
#
# /content/drive/My Drive/projects/snake-ai-pytorch/src/agent.py in train_short_memory(self, state, action, reward, next_state, done)
#     264
#     265     def train_short_memory(self, state, action, reward, next_state, done):
# --> 266         self.trainer.train_step(state, action, reward, next_state, done)
#     267
#     268     def update_rewards(self, game: SnakeGameAI, last_reward: int):
#
# /content/drive/My Drive/projects/snake-ai-pytorch/src/model.py in train_step(self, state, action, reward, next_state, done)
#      60                 Q_new = reward[idx] + self.gamma * torch.max(self.model(next_state[idx]))
#      61
# ---> 62             target[idx][torch.argmax(action[idx]).item()] = Q_new
#      63
#      64         # 2: Q_new = r + y * max(next_predicted Q value) -> only do this if not done
#
# IndexError: invalid index of a 0-dim tensor. Use tensor.item() to convert a 0-dim tensor to a Python number
